# %%
import pandas as pd
import pandas as pd 
import numpy as np
import scipy.stats as sts

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
bike_data_toload = "201908-citibike-tripdata.csv"

bike_df = pd.read_csv(bike_data_toload)

# %%
bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
# 2. Check the datatypes of your columns. 
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 268.3+ MB

# %%
# add an age column
bike_df['age'] = 2022 - bike_df['birth year']

# %%
pd.to_datetime(200, unit='s')
# Out:
# Timestamp('1970-01-01 00:03:20')

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
bike_df.tripduration = pd.to_datetime(bike_df.tripduration, unit='s')

# %%
bike_df.tail()
# Out:
#                tripduration                 starttime  \
# 2344219 1970-01-01 00:03:36  2019-08-31 23:59:46.2930
# 2344220 1970-01-01 00:01:57  2019-08-31 23:59:47.7970
# 2344221 1970-01-01 00:26:54  2019-08-31 23:59:48.1560
# 2344222 1970-01-01 00:21:41  2019-08-31 23:59:58.3620
# 2344223 1970-01-01 00:06:59  2019-08-31 23:59:59.4520
#
#                          stoptime  start station id  \
# 2344219  2019-09-01 00:03:23.0360             116.0
# 2344220  2019-09-01 00:01:45.7440            3429.0
# 2344221  2019-09-01 00:26:42.7760             387.0
# 2344222  2019-09-01 00:21:39.7040            3168.0
# 2344223  2019-09-01 00:06:59.0210             447.0
#
#                   start station name  start station latitude  \
# 2344219              W 17 St & 8 Ave               40.741776
# 2344220       Hanson Pl & Ashland Pl               40.685068
# 2344221      Centre St & Chambers St               40.712733
# 2344222  Central Park West & W 85 St               40.784727
# ...

# %%
# 4. Check the datatypes of your columns. 
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 16 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             datetime64[ns]
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
#  15  age                      float64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(5)
# memory usage: 286.2+ MB

# %%
# 5. Export the Dataframe as a new CSV file without the index.
bike_df.to_csv("modified_201908-citibike-tripdata.csv", index=False)

# %%
data_toload = "modified_201908-citibike-tripdata.csv"

df = pd.read_csv(data_toload)

# %%
df.sample(10)
# Out:
#                 tripduration                 starttime  \
# 1259881  1970-01-01 00:12:20  2019-08-17 10:32:36.7160
# 356385   1970-01-01 00:08:34  2019-08-05 16:14:48.6170
# 2024492  1970-01-01 00:05:59  2019-08-27 17:28:38.6180
# 540480   1970-01-01 00:03:32  2019-08-08 08:07:43.1730
# 2012872  1970-01-01 00:26:42  2019-08-27 15:26:18.2900
# 812779   1970-01-01 00:41:03  2019-08-11 15:38:51.1710
# 75301    1970-01-01 00:25:50  2019-08-01 20:07:47.6770
# 1041655  1970-01-01 00:33:01  2019-08-14 14:48:58.6540
# 2279336  1970-01-01 00:18:39  2019-08-30 23:31:09.8340
# 2179945  1970-01-01 00:11:06  2019-08-29 18:11:36.4680
#
#                          stoptime  start station id  \
# 1259881  2019-08-17 10:44:57.2720            3461.0
# 356385   2019-08-05 16:23:22.6750             291.0
# 2024492  2019-08-27 17:34:37.8780             293.0
# 540480   2019-08-08 08:11:15.9010            3507.0
# 2012872  2019-08-27 15:53:00.4070            3135.0
# ...
